# %% [markdown]
# # LoRa Data Analysis - Adaptive Data Rate

# %% [markdown]
# We first declare a fixed parameters.
#
# Those parameters are not changed during the experiments.
#
# Fixed communication parameters are listed below:
# - Code Rate: 4/5
# - Bandwidth: 125 kHz
#
# End nodes:
# - used an adaptive data rate algorithm (ADR) for communication parameters selection.
#
# Access points:
# - two access points were used to avoid a duty cycle depletion

# %% [markdown]
# Initial declaration

# %%
# %matplotlib inline
import pandas as pd # import pandas
import numpy as np # import numpy
import matplotlib as mpl # import matplotlib
import matplotlib_inline as mpl_inl # import matplotlib
import matplotlib.pyplot as plt # import plotting module
import statistics
import math
import base64
from IPython.display import set_matplotlib_formats # module for svg export

mpl_inl.backend_inline.set_matplotlib_formats('svg') # set export to svg file
cut_ratio = 0.05 # Values below 5% of mean value are simply cut from charts to make it more readable
subfolder = 'data/s1'
uplink_message_file = './' + subfolder + '/uplink_messages.csv'
algorithm = 'adr'

# %% [markdown]
# ## Analysis of Uplink Messages

# %% [markdown]
# We read a csv file with uplink messages

# %%
uplink_data = pd.read_csv(uplink_message_file, delimiter=',')

# %% [markdown]
# Let us have a look at various columns that are present and can be evaluated.

# %%
uplink_data.head()
# Out:
#       id      app_data    snr  rssi  duty_cycle_remaining is_primary  \
# 0  39039  QjVCQkJCAA==  11.50   -59                 33704          t
# 1  39040  QjVCQkJCAA==   9.50   -66                 33704          t
# 2  39041  QjVCQkJCAA==   8.75   -78                 32386          t
# 3  39042  QjVCQkJCAA==   8.50   -56                 31440          t
# 4  39043  QjVCQkJCAA==   6.25   -60                 31440          t
#
#               receive_time    seq  frequency  spf  ...     airtime  coderate  \
# 0  2023-09-20 18:45:08.249   2595  866100000   11  ... -1276574632       4/5
# 1  2023-09-20 18:45:08.706  37730  866500000   11  ... -1276573828       4/5
# 2  2023-09-20 18:45:12.737  49485  866300000   11  ... -1276570095       4/5
# 3  2023-09-20 18:45:16.273  18305  866100000   11  ... -1276566584       4/5
# 4  2023-09-20 18:45:18.777   6981  866900000   12  ... -1276563930       4/5
#
#   bandwidth  msg_group_number  message_type_id   ap_id  node_id dev_id  \
# 0    125000                22                1  777777     zMzM  39009
# 1    125000                17                1  777777     u7u7  39010
# 2    125000               105                1  777777     VVVV  39011
# 3    125000                23                1  777777     iIiI  39012
# 4    125000                27                1  777777     qqqq  39013
#
#    application_id  battery
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Let us have a look for different values to get an overview of overall values of different network parameters.

# %%
uplink_data.describe()
# Out:
#                  id          snr         rssi  duty_cycle_remaining  \
# count   2396.000000  2396.000000  2396.000000           2396.000000
# mean   40236.500000     8.609245   -77.038397          11271.395659
# std      691.809945     2.694731    12.941791          11410.675944
# min    39039.000000   -13.750000  -119.000000              1.000000
# 25%    39637.750000     7.750000   -84.000000            240.000000
# 50%    40236.500000     9.000000   -77.000000           8114.000000
# 75%    40835.250000    10.000000   -69.000000          19701.500000
# max    41434.000000    14.250000   -49.000000          36000.000000
#
#                 seq     frequency          spf   power       airtime  \
# count   2396.000000  2.396000e+03  2396.000000  2396.0  2.396000e+03
# mean   32710.121870  8.665313e+08    10.666110     0.0 -1.241451e+09
# std    17754.933886  3.153500e+05     1.779832     0.0  2.213398e+07
# min      133.000000  8.661000e+08     7.000000     0.0 -1.276575e+09
# 25%    18005.500000  8.663000e+08    10.000000     0.0 -1.262002e+09
# 50%    33264.000000  8.665000e+08    11.000000     0.0 -1.243973e+09
# 75%    47070.500000  8.669000e+08    12.000000     0.0 -1.222365e+09
# max    65525.000000  8.669000e+08    12.000000     0.0 -1.204326e+09
#
#        bandwidth  msg_group_number  message_type_id          ap_id  \
# count     2396.0       2396.000000           2396.0    2396.000000
# mean    125000.0        170.434891              1.0  562232.789649
# std          0.0         92.978703              0.0  222168.010382
# min     125000.0         16.000000              1.0  333333.000000
# 25%     125000.0         97.000000              1.0  333333.000000
# 50%     125000.0        160.000000              1.0  777777.000000
# 75%     125000.0        229.000000              1.0  777777.000000
# max     125000.0        411.000000              1.0  777777.000000
#
#              dev_id  application_id  battery
# count   2396.000000             0.0      0.0
# mean   40206.500000             NaN      NaN
# std      691.809945             NaN      NaN
# min    39009.000000             NaN      NaN
# 25%    39607.750000             NaN      NaN
# 50%    40206.500000             NaN      NaN
# 75%    40805.250000             NaN      NaN
# max    41404.000000             NaN      NaN

# %% [markdown]
# ### Payload Length

# %%
uplink_data['payload_len'] = uplink_data.app_data.apply(len)
uplink_data.payload_len.describe()
# Out:
# count    2396.0
# mean       12.0
# std         0.0
# min        12.0
# 25%        12.0
# 50%        12.0
# 75%        12.0
# max        12.0
# Name: payload_len, dtype: float64

# %%
payload_len = round(statistics.mean(uplink_data.payload_len), 2)
print(f'Mean value of payload length is {payload_len}.')
# Out:
# Mean value of payload length is 12.

# %% [markdown]
# ### Spreading Factor

# %%
hist = uplink_data.spf.value_counts().plot(kind='bar',rot=0,color='g',figsize=(6,3))
hist.set_xlabel('Spreading Factor',fontsize=12)
hist.set_ylabel('Number of Messages',fontsize=12)

plt.title(f'Utilization of Spreading Factor for {algorithm.upper()}')
plt.savefig(f'./{subfolder}/{algorithm}-speading-factor.svg', dpi=300)
plt.show()

# %% [markdown]
# ### Utilization of Frequency

# %% [markdown]
# Frequency is stored in Hz, so we need to convert it to MHz.

# %%
uplink_frequency = uplink_data.frequency / 1000000

# %%
hist = uplink_frequency.value_counts().plot(kind='bar',rot=0,color='g')
hist.set_xlabel('Frequency [MHz]',fontsize=12)
hist.set_ylabel('Number of Messages',fontsize=12)

plt.title(f'Utilization of Frequencies for {algorithm.upper()}')
plt.savefig(f'./{subfolder}/{algorithm}-frequencies.svg', dpi=300)
plt.show()

# %% [markdown]
# ### Unique Uplink Messages

# %%
unique_messages = uplink_data[uplink_data.is_primary=="t"]
print(f'Uplink messages received during experiment: {len(unique_messages)}')
# Out:
# Uplink messages received during experiment: 2024

# %% [markdown]
# ### Received Signal Strength Indicator

# %%
x = unique_messages.id
y = unique_messages.rssi
hist.set_xlabel('Time', fontsize=12)
#hist.set_ylabel('Number of Messages', fontsize=12)

# size and color:
sizes = np.random.uniform(15, 80, len(x))

# Define the colormap 'Greens' which is a gradient of green
cmap = plt.get_cmap('Greens')

# Define vmin and vmax values to control the gradient
vmin = 0.2
vmax = 0.8

# Generate random values within the range [vmin, vmax]
normalized_values = (np.random.rand(len(x)) * (vmax - vmin)) + vmin

fig, ax = plt.subplots()
sc = ax.scatter(x, y, s=sizes, c=normalized_values, cmap=cmap, vmin=vmin, vmax=vmax)

# Add colorbar for reference
cbar = plt.colorbar(sc)
cbar.set_label('Color Range')

ax.set_xticks([])

plt.title(f'RSSI values in time for {algorithm.upper()}')
plt.savefig(f'./{subfolder}/{algorithm}-rssi.svg', dpi=300)
plt.show()

# %% [markdown]
# ## Analysis of End Nodes

# %% [markdown]
# Analysis of certain aspects of end devices.

# %%
print(f'Number of end nodes partiipating in the experiment is {uplink_data.node_id.nunique()}.')
# Out:
# Number of end nodes partiipating in the experiment is 10.

# %%
uplink_data.node_id.describe()
# Out:
# count     2396
# unique      10
# top       VVVV
# freq       362
# Name: node_id, dtype: object

# %%
unique_ens = len(uplink_data.node_id.unique())
unique_aps = len(uplink_data.ap_id.unique())

print(f'Total number of connected end devices: {unique_ens}')
print(f'Total number of connected access points: {unique_aps}')
# Out:
# Total number of connected end devices: 10
# Total number of connected access points: 2

# %% [markdown]
# ## End Nodes CSV Protocol Analysis

# %%
dev_id = 'zMzM'
end_nodes_file = f'./{subfolder}/{dev_id}.csv'

end_nodes = pd.read_csv(end_nodes_file, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[91], line 4
#       1 dev_id = 'zMzM'
#       2 end_nodes_file = f'./{subfolder}/{dev_id}.csv'
# ----> 4 end_nodes = pd.read_csv(end_nodes_file, delimiter=',')
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/s1r2/zMzM.csv'

# %%
end_nodes.head()
# Out:
#         id      app_data    snr  rssi  duty_cycle_remaining is_primary  \
# 0    39039  QjVCQkJCAA==  11.50   -59                 33704          t
# 1    39040  QjVCQkJCAA==   9.50   -66                 33704          t
# 2    39041  QjVCQkJCAA==   8.75   -78                 32386          t
# 3    39042  QjVCQkJCAA==   8.50   -56                 31440          t
# 4    39043  QjVCQkJCAA==   6.25   -60                 31440          t
# 5    39044  QjVCQkJCAA==  11.25   -97                   108          t
# 6    39045  QjVCQkJCAA==   6.25   -77                   108          t
# 7    39046  QjVCQkJCAA==   9.00   -54                 29343          t
# 8    39047  QjVCQkJCAA==   8.50   -60                 27823          t
# 9    39048  QjVCQkJCAA==   5.00   -79                   108          t
# 68   2023-09-20 18:47:13.906  21562  866500000   12  ...       4/5     125000
# 69   2023-09-20 18:47:16.382  61283  866500000   12  ...       4/5     125000
# 71   2023-09-20 18:47:16.451  27730  866100000    8  ...       4/5     125000
# 114  2023-09-20 19:45:32.306   6127  866100000   11  ...       4/5     125000
# 119  2023-09-20 19:45:44.335   6129  866300000   10  ...       4/5     125000
# 121  2023-09-20 19:45:46.341  42152  866100000   11  ...       4/5     125000
#
#     msg_group_number  message_type_id   ap_id  node_id  dev_id application_id  \
# 0                 22                1  777777     zMzM   39009            NaN
# 1                 17                1  777777     u7u7   39010            NaN
# 2                105                1  777777     VVVV   39011            NaN
# 3                 23                1  777777     iIiI   39012            NaN
# 4                 27                1  777777     qqqq   39013            NaN
# 5                 23                1  333333     zMzM   39014            NaN
# 6                106                1  333333     VVVV   39015            NaN
# 7                 30                1  777777     7u7u   39016            NaN
# 8                 28                1  777777     qqqq   39017            NaN
# 9                107                1  333333     VVVV   39018            NaN
# 10                18                1  777777     u7u7   39019            NaN
# 11               108                1  333333     VVVV   39020            NaN
# 12                24                1  777777     iIiI   39021            NaN
# 13                89                1  777777     d3d3   39022            NaN
# 14                25                1  333333     iIiI   39023            NaN
# 15                24                1  777777     zMzM   39024            NaN
# 16                19                1  777777     u7u7   39025            NaN
# 18               109                1  777777     VVVV   39027            NaN
# 19                26                1  777777     iIiI   39028            NaN
# 20                90                1  777777     d3d3   39029            NaN
# 22                27                1  333333     iIiI   39031            NaN
# 23                20                1  777777     u7u7   39032            NaN
# 24                25                1  333333     zMzM   39033            NaN
# 26                46                1  777777     3d3d   39035            NaN
# 27                91                1  777777     d3d3   39036            NaN
# 28                16                1  333333     mZmZ   39037            NaN
# 29                21                1  777777     u7u7   39038            NaN
# 30                26                1  777777     zMzM   39039            NaN
# 31                29                1  333333     qqqq   39040            NaN
# 32                17                1  333333     mZmZ   39041            NaN
# 34                92                1  333333     d3d3   39043            NaN
# 35                85                1  333333     ZmZm   39044            NaN
# 37                86                1  333333     ZmZm   39046            NaN
# 39                47                1  777777     3d3d   39048            NaN
# 42                93                1  333333     d3d3   39051            NaN
# 43                18                1  777777     mZmZ   39052            NaN
# 45                87                1  333333     ZmZm   39054            NaN
# 46                31                1  777777     7u7u   39055            NaN
# 49                19                1  777777     mZmZ   39058            NaN
# 50                48                1  777777     3d3d   39059            NaN
# 54                32                1  777777     7u7u   39063            NaN
# 58                30                1  777777     qqqq   39067            NaN
# 59                88                1  333333     ZmZm   39068            NaN
# 61                33                1  777777     7u7u   39070            NaN
# 68                31                1  777777     qqqq   39077            NaN
# 69                89                1  333333     ZmZm   39078            NaN
# 71                34                1  777777     7u7u   39080            NaN
# 114               49                1  777777     3d3d   39123            NaN
# 119               50                1  333333     3d3d   39128            NaN
# 121               20                1  777777     mZmZ   39130            NaN
#
#      battery  payload_len
# 0        NaN           12
# 1        NaN           12
# 2        NaN           12
# 3        NaN           12
# 4        NaN           12
# 5        NaN           12
# 6        NaN           12
# 7        NaN           12
# 8        NaN           12
# 9        NaN           12
# 10       NaN           12
# 11       NaN           12
# 12       NaN           12
# 13       NaN           12
# 14       NaN           12
# 15       NaN           12
# 16       NaN           12
# 18       NaN           12
# 19       NaN           12
# 20       NaN           12
# 22       NaN           12
# 23       NaN           12
# 24       NaN           12
# 26       NaN           12
# 27       NaN           12
# 28       NaN           12
# 29       NaN           12
# 30       NaN           12
# 31       NaN           12
# 32       NaN           12
# 34       NaN           12
# 35       NaN           12
# 37       NaN           12
# 39       NaN           12
# 42       NaN           12
# 43       NaN           12
# 45       NaN           12
# 46       NaN           12
# 49       NaN           12
# 50       NaN           12
# 54       NaN           12
# 58       NaN           12
# 59       NaN           12
# 61       NaN           12
# 68       NaN           12
# 69       NaN           12
# 71       NaN           12
# 114      NaN           12
# 119      NaN           12
# 121      NaN           12
#
# [50 rows x 22 columns]

# %%
end_nodes.describe()
# Out:
#             id                                                         \
#          count          mean          std      min       25%      50%
# node_id
# 3d3d     251.0  40951.796813  1116.863653  39065.0  39949.50  40916.0
# 7u7u     278.0  40465.187050   830.640070  39046.0  39718.75  40421.5
# VVVV     581.0  41308.791738  1317.182166  39041.0  40204.00  41273.0
# ZmZm     354.0  40705.963277  1093.458560  39074.0  39814.75  40626.5
# d3d3     339.0  40585.356932  1091.808743  39052.0  39726.50  40396.0
# iIiI     274.0  40677.562044  1155.685413  39042.0  39714.00  40471.5
# mZmZ     322.0  42248.770186  1011.967362  39067.0  41919.00  42469.0
# qqqq     185.0  41382.329730  1072.493866  39043.0  40857.00  41393.0
# u7u7     444.0  41636.695946  1448.746849  39040.0  40213.50  42178.5
# zMzM     286.0  40681.748252  1155.598179  39039.0  39687.50  40533.5
#
#                               snr             ... battery     payload_len  \
#               75%      max  count       mean  ...     75% max       count
# node_id                                       ...
# 3d3d     41708.00  43557.0  251.0   7.943227  ...     NaN NaN       251.0
# 7u7u     41204.75  41744.0  278.0   9.093525  ...     NaN NaN       278.0
# VVVV     42479.00  43552.0  581.0   9.445353  ...     NaN NaN       581.0
# ZmZm     41348.25  43570.0  354.0   8.352401  ...     NaN NaN       354.0
# d3d3     41254.00  43569.0  339.0   8.902655  ...     NaN NaN       339.0
# iIiI     41375.25  43566.0  274.0   8.670620  ...     NaN NaN       274.0
# mZmZ     42982.00  43529.0  322.0  10.500000  ...     NaN NaN       322.0
# qqqq     41837.00  43574.0  185.0   8.678378  ...     NaN NaN       185.0
# u7u7     42937.50  43560.0  444.0   9.581081  ...     NaN NaN       444.0
# zMzM     41390.50  43572.0  286.0   8.306818  ...     NaN NaN       286.0
#
#
#          mean  std   min   25%   50%   75%   max
# node_id
# 3d3d     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# 7u7u     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# VVVV     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# ZmZm     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# d3d3     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# iIiI     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# mZmZ     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# qqqq     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# u7u7     12.0  0.0  12.0  12.0  12.0  12.0  12.0
# zMzM     12.0  0.0  12.0  12.0  12.0  12.0  12.0
#
# [10 rows x 136 columns]

# %%
hist = end_nodes.frequency.value_counts().plot(kind='bar',rot=0,color='g')
hist.set_xlabel('Frequency [MHz]',fontsize=12)
hist.set_ylabel('Messages',fontsize=12)

plt.title(f'Utilization of Frequencies for {dev_id} for {algorithm.upper()}')
plt.savefig(f'./{subfolder}/{algorithm}-{dev_id}-frequencies.svg', dpi=300)
plt.show()

# %%
hist = end_nodes.sf.value_counts().plot(kind='bar',rot=0,color='g')
hist.set_xlabel('Spreading Factor',fontsize=12)
hist.set_ylabel('Transmission Attempts',fontsize=12)

plt.title(f'Utilization of Frequencies for {dev_id} for {algorithm.upper()}')
plt.savefig(f'./{subfolder}/{algorithm}-{dev_id}-sf.svg', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 hist = end_nodes.sf.value_counts().plot(kind='bar',rot=0,color='g')
#       2 hist.set_xlabel('Spreading Factor',fontsize=12)
#       3 hist.set_ylabel('Transmission Attempts',fontsize=12)
#
# File /opt/jupyter/jupyter-env/jupyter-env/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'sf'

# %% [markdown]
# ## Packet Delivery Raio

# %% [markdown]
# Evaluation of PDR for end nodes.

# %%
end_nodes = unique_messages.groupby('node_id')

seq_tolerance = 15
first_seq = 0
last_seq = 0
prev_seq = 0
prev_node_id = ""
msg_count = 0
msg_delivered = 0
total_msg_count = 0

for name,group in end_nodes:
    #print('ID:' + str(name))
    #print(group['seq'])

    for seq in group['seq']:
        #print(name, seq)
        if (abs(prev_seq - seq) > seq_tolerance):
            total_msg_count += prev_seq - first_seq
            #print(prev_node_id, prev_seq, seq, first_seq, prev_seq - first_seq, msg_count)
            msg_delivered += msg_count
            first_seq = seq
            msg_count = 0
        if prev_seq != seq:
            msg_count += 1
        prev_seq = seq
        prev_node_id = name
    if total_msg_count != 0:
        pdr = min(round(msg_delivered / total_msg_count * 100, 2), 100.0)
    else:
        pdr = 0.0
    print(f'{name} reached PDR {pdr}%')
    first_seq = 0
    last_seq = 0
    prev_seq = 0
    msg_count = 0
    msg_delivered = 0
    total_msg_count = 0
# Out:
# 3d3d reached PDR 81.82%
# 7u7u reached PDR 74.23%
# VVVV reached PDR 73.19%
# ZmZm reached PDR 75.58%
# d3d3 reached PDR 71.05%
# iIiI reached PDR 72.57%
# mZmZ reached PDR 87.01%
# qqqq reached PDR 66.43%
# u7u7 reached PDR 71.59%
# zMzM reached PDR 71.86%

# %% [markdown]
# The End.
