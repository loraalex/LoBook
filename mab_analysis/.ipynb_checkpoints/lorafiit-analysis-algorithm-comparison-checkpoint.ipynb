# %% [markdown]
# # LoRa Data Analysis - Algorithm Comparison

# %% [markdown]
# We first declare a fixed parameters.
#
# Those parameters are not changed during the experiments.
#
# Fixed communication parameters are listed below:
# - Code Rate: 4/5
# - Bandwidth: 125 kHz
# - Payload length: 12 B
#
# End nodes:
# - used an adaptive data rate algorithm (ADR) for communication parameters selection.
#
# Access points:
# - two access points were used to avoid a duty cycle depletion

# %% [markdown]
# Initial declaration

# %%
# %matplotlib inline
import pandas as pd # import pandas
import numpy as np # import numpy
import matplotlib as mpl # import matplotlib
import matplotlib_inline as mpl_inl # import matplotlib
import matplotlib.pyplot as plt # import plotting module
import statistics
import math
import base64
from IPython.display import set_matplotlib_formats # module for svg export
from IPython.display import display

mpl_inl.backend_inline.set_matplotlib_formats('svg') # set export to svg file
cut_ratio = 0.05 # Values below 5% of mean value are simply cut from charts to make it more readable
subfolders = ['s4r5', 's5r5']
algorithms = ['ts_aloha', 'ts_cad']
colors = ['pink', 'tab:purple']
output_format = 'png'
uplink_message_files = []
dataset_labels = []
subfolder_str = '-'.join(subfolders) 

for alg, subfolder in zip(algorithms, subfolders):
    uplink_message_files.append('./data/' + alg + '/' + subfolder + '/uplink_messages.csv')
    dataset_labels.append(alg.upper())

# %% [markdown]
# ## Analysis of Uplink Messages

# %% [markdown]
# We read a csv file with uplink messages

# %%
uplink_data = []

for file in uplink_message_files:
    uplink_data.append(pd.read_csv(file, delimiter=','))

# %% [markdown]
# Let us have a look at various columns that are present and can be evaluated.

# %%
for index, data in enumerate(uplink_data):
    print(dataset_labels[index])
    display(data.head())
# Out:
# TS_ALOHA
#       id      app_data    snr  rssi  duty_cycle_remaining is_primary  \
# 0  58503  QjVCQkJCAA==  10.00   -96                 33867          t
# 1  58504  QjVCQkJCAA==  10.00   -98                 33867          t
# 2  58505  QjVCQkJCAA==  10.75   -96                 33293          t
# 3  58506  QjVCQkJCAA==  10.50  -100                 32959          t
# 4  58507  QjVCQkJCAA==   8.25   -88                 30793          t
#
#               receive_time    seq  frequency  spf  ...     airtime  coderate  \
# 0  2023-10-26 11:08:31.032  17049  866700000    8  ...  1806428425       4/7
# 1  2023-10-26 11:08:32.034  21607  866700000   10  ...  1806429407       4/7
# 2  2023-10-26 11:08:34.047  17050  866700000    8  ...  1806431588       4/7
# 3  2023-10-26 11:08:35.572  21608  866700000   10  ...  1806432901       4/7
# 4  2023-10-26 11:08:44.675  55118  866500000   10  ...  1806442167       4/7
#
#   bandwidth  msg_group_number  message_type_id   ap_id  node_id dev_id  \
# 0    125000              1701                1  333333     qqqq  58473
# 1    125000              2161                1  333333     u7u7  58474
# 2    125000              1702                1  333333     qqqq  58475
# 3    125000              2162                1  333333     u7u7  58476
# 4    125000              2730                1  333333     RERE  58477
#
#    application_id  battery
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
#
# [5 rows x 21 columns]
# TS_CAD
#       id      app_data    snr  rssi  duty_cycle_remaining is_primary  \
# 0  54180  QjVCQkJCAA==   9.00  -105                 34401          t
# 1  54181  QjVCQkJCAA==  10.75  -101                 32566          t
# 2  54182  QjVCQkJCAA==  11.50   -67                    26          t
# 3  54183  QjVCQkJCAA==  11.50   -71                    26          f
# 4  54184  QjVCQkJCAA==   8.50  -105                 29829          t
#
#               receive_time    seq  frequency  spf  ...     airtime  coderate  \
# 0  2023-10-25 13:44:59.242  31998  866700000    8  ...  1729416778       4/7
# 1  2023-10-25 13:45:06.297  45117  866100000    9  ...  1729423159       4/7
# 2  2023-10-25 13:45:10.329  32000  866700000    8  ...  1729427617       4/7
# 3  2023-10-25 13:45:13.334  32001  866700000    8  ...  1729430775       4/7
# 4  2023-10-25 13:45:13.336  32001  866700000    8  ...  1729430770       4/7
#
#   bandwidth  msg_group_number  message_type_id   ap_id  node_id dev_id  \
# 0    125000              2098                1  333333     RERE  54150
# 1    125000              1729                1  333333     u7u7  54151
# 2    125000              2099                1  777777     RERE  54152
# 3    125000              2100                1  777777     RERE  54153
# 4    125000              2100                1  333333     RERE  54154
#
#    application_id  battery
# 0             NaN      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4             NaN      NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Let us have a look for different values to get an overview of overall values of different network parameters.

# %%
for index, data in enumerate(uplink_data):
    print(dataset_labels[index])
    display(data.describe())
# Out:
# TS_ALOHA
#                  id         snr        rssi  duty_cycle_remaining  \
# count    275.000000  275.000000  275.000000            275.000000
# mean   58640.000000    9.489091  -90.796364          11928.320000
# std       79.529869    3.420949    8.190834          10910.343764
# min    58503.000000  -11.500000 -109.000000              6.000000
# 25%    58571.500000    8.750000  -97.000000             33.000000
# 50%    58640.000000   10.500000  -91.000000          10878.000000
# 75%    58708.500000   11.250000  -85.000000          21061.000000
# max    58777.000000   18.250000  -74.000000          33867.000000
#
#                 seq     frequency         spf  power       airtime  bandwidth  \
# count    275.000000  2.750000e+02  275.000000  275.0  2.750000e+02      275.0
# mean   34163.909091  8.664542e+08    9.021818    0.0  1.810115e+09   125000.0
# std    18916.762407  2.512937e+05    1.261255    0.0  2.878663e+06        0.0
# min      260.000000  8.661000e+08    7.000000    0.0  1.806428e+09   125000.0
# 25%    17054.000000  8.663000e+08    8.000000    0.0  1.806583e+09   125000.0
# 50%    42860.000000  8.663000e+08   10.000000    0.0  1.810131e+09   125000.0
# 75%    49529.500000  8.667000e+08   10.000000    0.0  1.813691e+09   125000.0
# max    61876.000000  8.669000e+08   12.000000    0.0  1.814047e+09   125000.0
#
#        msg_group_number  message_type_id     ap_id        dev_id  \
# count        275.000000            275.0     275.0    275.000000
# mean        1978.374545              1.0  333333.0  58610.000000
# std          828.831674              0.0       0.0     79.529869
# min           97.000000              1.0  333333.0  58473.000000
# 25%         1706.500000              1.0  333333.0  58541.500000
# 50%         2163.000000              1.0  333333.0  58610.000000
# 75%         2753.500000              1.0  333333.0  58678.500000
# max         3047.000000              1.0  333333.0  58747.000000
#
#        application_id  battery
# count             0.0      0.0
# mean              NaN      NaN
# std               NaN      NaN
# min               NaN      NaN
# 25%               NaN      NaN
# 50%               NaN      NaN
# 75%               NaN      NaN
# max               NaN      NaN
# TS_CAD
#                  id         snr        rssi  duty_cycle_remaining  \
# count    990.000000  990.000000  990.000000            990.000000
# mean   54674.500000    9.655808  -87.367677           8647.914141
# std      285.932684    3.184625   13.933185           9741.878578
# min    54180.000000  -11.750000 -115.000000             15.000000
# 25%    54427.250000    8.500000  -99.000000             29.000000
# 50%    54674.500000   10.500000  -91.000000           5440.000000
# 75%    54921.750000   11.750000  -72.000000          15360.000000
# max    55169.000000   19.000000  -60.000000          34401.000000
#
#                 seq     frequency         spf  power       airtime  bandwidth  \
# count    990.000000  9.900000e+02  990.000000  990.0  9.900000e+02      990.0
# mean   35954.454545  8.665362e+08    8.387879    0.0  1.733029e+09   125000.0
# std    19286.101458  2.721027e+05    0.828618    0.0  2.754498e+06        0.0
# min      759.000000  8.661000e+08    7.000000    0.0  1.729417e+09   125000.0
# 25%    20295.000000  8.663000e+08    8.000000    0.0  1.729853e+09   125000.0
# 50%    36105.500000  8.665000e+08    8.000000    0.0  1.733231e+09   125000.0
# 75%    54216.000000  8.667000e+08    9.000000    0.0  1.736630e+09   125000.0
# max    64929.000000  8.669000e+08   12.000000    0.0  1.737393e+09   125000.0
#
#        msg_group_number  message_type_id          ap_id        dev_id  \
# count        990.000000            990.0     990.000000    990.000000
# mean        1614.377778              1.0  503927.666667  54644.500000
# std          643.851827              0.0  216250.948155    285.932684
# min          210.000000              1.0  333333.000000  54150.000000
# 25%         1227.000000              1.0  333333.000000  54397.250000
# 50%         1771.500000              1.0  333333.000000  54644.500000
# 75%         2172.750000              1.0  777777.000000  54891.750000
# max         2371.000000              1.0  777777.000000  55139.000000
#
#        application_id  battery
# count             0.0      0.0
# mean              NaN      NaN
# std               NaN      NaN
# min               NaN      NaN
# 25%               NaN      NaN
# 50%               NaN      NaN
# 75%               NaN      NaN
# max               NaN      NaN

# %% [markdown]
# ### Picking up only Unique Uplink Messages

# %%
unique_messages = []

for index, data in enumerate(uplink_data):
    unique_messages.append(data[data.is_primary=="t"])
    print(f'Uplink messages received during {dataset_labels[index]} experiment: {len(unique_messages[index])}')
# Out:
# Uplink messages received during TS_ALOHA experiment: 275
# Uplink messages received during TS_CAD experiment: 727

# %% [markdown]
# ### Spreading Factor

# %%
sfs = []

for index, data in enumerate(unique_messages):
    sfs.append(data.spf.value_counts())

# Find the union of all columns in all datasets
all_columns = set().union(*(df.index for df in sfs))

# Create a dictionary of DataFrames with the same columns for all datasets
datasets_dict = {}
for idx, df in enumerate(sfs):
    # Fill missing columns with 0
    df = df.reindex(all_columns, fill_value=0)
    datasets_dict[dataset_labels[idx]] = df

# Convert the dictionary to a list of pairs (DataFrame, label)
results = [(df, label) for label, df in datasets_dict.items()]

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Define bar width.
bar_width = 1 / (len(algorithms) + 1)
index = np.arange(len(results[0][0].index))

for idx, (data, label) in enumerate(results):
    # Drop NA values before calculations
    data_cleaned = data.dropna()
    
    ax.bar(index + idx * bar_width, data_cleaned, width=bar_width, label=label, color=colors[idx])

# Set x-ticks and labels
ax.set_xticks(index + bar_width * (len(results) - 1) / 2)
ax.set_xticklabels(results[0][0].index)

# Add a legend
ax.legend()

# Axis styling
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels
ax.set_xlabel('Spreading Factor', labelpad=15)
ax.set_ylabel('Number of Messages', labelpad=15)
ax.set_title('Spreading Factor Distribution', pad=15)

# For each bar in the chart, add a text label
for bar in ax.patches:
    bar_value = round(bar.get_height())
    text = f'{bar_value:,}'
    text_x = bar.get_x() + bar.get_width() / 2
    text_y = bar.get_y() + bar_value
    ax.text(text_x, text_y, text, ha='center', va='bottom', color='black', size=10)

filename = f'algorithms-sf-{subfolder_str}.{output_format}'
fig.savefig(filename, dpi=300)

plt.show()

# %% [markdown]
# ### Utilization of Frequency

# %% [markdown]
# Frequency is stored in Hz, so we need to convert it to MHz.

# %%
cfs = []

for index, data in enumerate(unique_messages):
    cfs.append(data.frequency.value_counts())

# Find the union of all columns in all datasets
all_columns = set().union(*(df.index for df in cfs))

# Create a dictionary of DataFrames with the same columns for all datasets
datasets_dict = {}
for idx, df in enumerate(cfs):
    # Fill missing columns with 0
    df = df.reindex(all_columns, fill_value=0)
    datasets_dict[dataset_labels[idx]] = df

# Convert the dictionary to a list of pairs (DataFrame, label)
results = [(df, label) for label, df in datasets_dict.items()]

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# Define bar width.
bar_width = 1 / (len(algorithms) + 1)
index = np.arange(len(results[0][0].index))

for idx, (data, label) in enumerate(results):
    # Drop NA values before calculations
    data_cleaned = data.dropna()
    
    ax.bar(index + idx * bar_width, data_cleaned, width=bar_width, label=label, color=colors[idx])

# Set x-ticks and labels
ax.set_xticks(index + bar_width * (len(results) - 1) / 2)
ax.set_xticklabels(results[0][0].index / 1000000)

# Add a legend
ax.legend()

# Axis styling
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

# Add axis and chart labels
ax.set_xlabel('Carrier Frequency [MHz]', labelpad=15)
ax.set_ylabel('Number of Messages', labelpad=15)
ax.set_title('Carrier Frequency Distribution', pad=15)

# For each bar in the chart, add a text label
for bar in ax.patches:
    bar_value = round(bar.get_height())
    text = f'{bar_value:,}'
    text_x = bar.get_x() + bar.get_width() / 2
    text_y = bar.get_y() + bar_value
    ax.text(text_x, text_y, text, ha='center', va='bottom', color='black', size=10)

filename = f'algorithms-cf-{subfolder_str}.{output_format}'
fig.savefig(filename, dpi=300)

plt.show()

# %% [markdown]
# ### Number of Unique Message per End Nodes

# %%
message_counts = []
unique_message_counts = []
recommended_messages = 154

for idx, data in enumerate(unique_messages):
    message_counts.append(data.node_id.value_counts().reset_index())
    message_counts[idx].columns = ['node_id', dataset_labels[idx]]

node_id_column = message_counts[0]['node_id']

result = pd.concat([node_id_column] + [df.drop('node_id', axis=1) for df in message_counts], axis=1)
result = result.fillna(0)

for label in dataset_labels:
    result[f'PDR ({label})'] = round((result[label] / recommended_messages) * 100, 2)

print(result)
# Out:
#   node_id  TS_ALOHA  TS_CAD  PDR (TS_ALOHA)  PDR (TS_CAD)
# 0    qqqq        57     141           37.01         91.56
# 1    3d3d        51     139           33.12         90.26
# 2    u7u7        47     135           30.52         87.66
# 3    RERE        42     114           27.27         74.03
# 4    VVVV        40      79           25.97         51.30
# 5    d3d3        15      59            9.74         38.31
# 6    ZmZm        10      24            6.49         15.58
# 7    mZmZ        10      20            6.49         12.99
# 8    iIiI         3      16            1.95         10.39

# %%
for label in dataset_labels:
    mean_value = round(result[f'PDR ({label})'].mean(), 2)
    print(f'Mean PDR for {label} is {mean_value}%')
# Out:
# Mean PDR for TS_ALOHA is 19.84%
# Mean PDR for TS_CAD is 52.45%

# %% [markdown]
# Convert the table to LaTeX

# %%
num_columns = len(result.columns)
column_format = '| X ' * (num_columns - 1) + '| X |'
latex_code = result.to_latex(index=False, column_format=column_format)
print(latex_code)
# Out:
# \begin{tabular}{| X | X | X | X | X |}
# \toprule
# node_id & TS_ALOHA & TS_CAD & PDR (TS_ALOHA) & PDR (TS_CAD) \\
# \midrule
# qqqq & 57 & 141 & 37.010000 & 91.560000 \\
# 3d3d & 51 & 139 & 33.120000 & 90.260000 \\
# u7u7 & 47 & 135 & 30.520000 & 87.660000 \\
# RERE & 42 & 114 & 27.270000 & 74.030000 \\
# VVVV & 40 & 79 & 25.970000 & 51.300000 \\
# d3d3 & 15 & 59 & 9.740000 & 38.310000 \\
# ZmZm & 10 & 24 & 6.490000 & 15.580000 \\
# mZmZ & 10 & 20 & 6.490000 & 12.990000 \\
# iIiI & 3 & 16 & 1.950000 & 10.390000 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Export LaTeX to file.

# %%
#file_path = f'message-count-{subfolder_str}.tex'

#with open(file_path, 'w') as file:
#    file.write(latex_code)

#print(f'The LaTeX table has been saved to {file_path}')

# %% [markdown]
# The End.
